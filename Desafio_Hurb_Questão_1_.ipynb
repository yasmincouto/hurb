# %%
#Extração de dados Pokédex - Candidata Yasmin Couto

# %%
#Importando pacotes e requisitos para coleta
import requests
import pandas as pd

# %%
##Espécies dos Pokemons

# %%
#Requisitando dados das especies e verificando status da resposta
especies = requests.get("https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0")
pokedex_especies = especies.json()

print("Status da requisição:",especies.status_code)
print("Chaves da requisição:",pokedex_especies.keys())
# Out:
# Status da requisição: 200
# Chaves da requisição: dict_keys(['count', 'next', 'previous', 'results'])

# %%
#Criando dataframe base df_especies a partir da requisição e selecionando 151 especies de interesse

df_especies = pd.DataFrame.from_dict(pokedex_especies)
df_especies = df_especies['results']
df_especies = df_especies.apply(pd.Series)
df_especies = df_especies[:151]
df_especies = df_especies.rename(columns={'name': 'Pokemon'})

print(df_especies.shape)
df_especies.tail()
# Out:
# (151, 2)
#        Pokemon                                     url
# 146    dratini  https://pokeapi.co/api/v2/pokemon/147/
# 147  dragonair  https://pokeapi.co/api/v2/pokemon/148/
# 148  dragonite  https://pokeapi.co/api/v2/pokemon/149/
# 149     mewtwo  https://pokeapi.co/api/v2/pokemon/150/
# 150        mew  https://pokeapi.co/api/v2/pokemon/151/

# %%
#Criando função para requisitar habilidades de cada espécie

def get_informacoes(i):
    r = requests.get(i)
    return r

# %%
#Criando loop para interar entre linhas do dataframe base df_especies
#Requisições serão armazenadas na lista req_informacoes

req_informacoes = []
for i in df_especies['url']:
  x = get_informacoes(i).json()
  req_informacoes.append(x)

# %%
#Criando o dataframe df que armazena as características de cada espécie
df = pd.DataFrame(req_informacoes)
df.head(1)
# Out:
#                                            abilities  base_experience  \
# 0  [{'ability': {'name': 'overgrow', 'url': 'http...               64
#
#                                                forms  \
# 0  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
#
#                                         game_indices  height held_items  id  \
# 0  [{'game_index': 153, 'version': {'name': 'red'...       7         []   1
#
#    is_default                        location_area_encounters  \
# 0        True  https://pokeapi.co/api/v2/pokemon/1/encounters
#
#                                                moves       name  order  \
# 0  [{'move': {'name': 'razor-wind', 'url': 'https...  bulbasaur      1
#
#   past_types                                            species  \
# 0         []  {'name': 'bulbasaur', 'url': 'https://pokeapi....
#
#                                              sprites  \
# 0  {'back_default': 'https://raw.githubuserconten...
#
#                                                stats  \
# 0  [{'base_stat': 45, 'effort': 0, 'stat': {'name...
#
#                                                types  weight
# 0  [{'slot': 1, 'type': {'name': 'grass', 'url': ...      69

# %%
##Forças dos Pokemons

# %%
#Estudando a documentação da API, stats representam as forças de cada pokemon:
  #stats(0)= HP
  #stats(1)= Ataque
  #stats(2)= Defesa
  #stats(3)= Ataque Especial 
  #stats(4)= Defesa Especial 
  #stats(5)= Velocidade

#Informações de stats coletadas ficam armazanadas no dataframe df_stats

df_stats = df['stats'].apply(pd.Series)
df_stats.head()
# Out:
#                                                    0  \
# 0  {'base_stat': 45, 'effort': 0, 'stat': {'name'...
# 1  {'base_stat': 60, 'effort': 0, 'stat': {'name'...
# 2  {'base_stat': 80, 'effort': 0, 'stat': {'name'...
# 3  {'base_stat': 39, 'effort': 0, 'stat': {'name'...
# 4  {'base_stat': 58, 'effort': 0, 'stat': {'name'...
#
#                                                    1  \
# 0  {'base_stat': 49, 'effort': 0, 'stat': {'name'...
# 1  {'base_stat': 62, 'effort': 0, 'stat': {'name'...
# 2  {'base_stat': 82, 'effort': 0, 'stat': {'name'...
# 3  {'base_stat': 52, 'effort': 0, 'stat': {'name'...
# 4  {'base_stat': 64, 'effort': 0, 'stat': {'name'...
#
#                                                    2  \
# 0  {'base_stat': 49, 'effort': 0, 'stat': {'name'...
# 1  {'base_stat': 63, 'effort': 0, 'stat': {'name'...
# 2  {'base_stat': 83, 'effort': 0, 'stat': {'name'...
# 3  {'base_stat': 43, 'effort': 0, 'stat': {'name'...
# 4  {'base_stat': 58, 'effort': 0, 'stat': {'name'...
#
#                                                    3  \
# 0  {'base_stat': 65, 'effort': 1, 'stat': {'name'...
# 1  {'base_stat': 80, 'effort': 1, 'stat': {'name'...
# 2  {'base_stat': 100, 'effort': 2, 'stat': {'name...
# 3  {'base_stat': 60, 'effort': 0, 'stat': {'name'...
# 4  {'base_stat': 80, 'effort': 1, 'stat': {'name'...
#
#                                                    4  \
# 0  {'base_stat': 65, 'effort': 0, 'stat': {'name'...
# 1  {'base_stat': 80, 'effort': 1, 'stat': {'name'...
# 2  {'base_stat': 100, 'effort': 1, 'stat': {'name...
# 3  {'base_stat': 50, 'effort': 0, 'stat': {'name'...
# 4  {'base_stat': 65, 'effort': 0, 'stat': {'name'...
#
#                                                    5
# 0  {'base_stat': 45, 'effort': 0, 'stat': {'name'...
# 1  {'base_stat': 60, 'effort': 0, 'stat': {'name'...
# 2  {'base_stat': 80, 'effort': 0, 'stat': {'name'...
# 3  {'base_stat': 65, 'effort': 1, 'stat': {'name'...
# 4  {'base_stat': 80, 'effort': 1, 'stat': {'name'...

# %%
#Extraindo o stats(0) e mesclando na dataframe base
df_hp=df_stats[0].apply(pd.Series)
df_hp=df_hp[['base_stat']]
df_hp = df_hp.rename(columns={'base_stat': 'HP'})

pokedex_temp1 = pd.merge(df_especies['Pokemon'], df_hp, left_index=True, right_index=True)
pokedex_temp1.head()
# Out:
#       Pokemon  HP
# 0   bulbasaur  45
# 1     ivysaur  60
# 2    venusaur  80
# 3  charmander  39
# 4  charmeleon  58

# %%
#Extraindo o stats(1) e mesclando na dataframe base
df_ataque=df_stats[1].apply(pd.Series)
df_ataque=df_ataque[['base_stat']]
df_ataque = df_ataque.rename(columns={'base_stat': 'Ataque'})

pokedex_temp2 = pd.merge(pokedex_temp1, df_ataque, left_index=True, right_index=True)
pokedex_temp2.head()
# Out:
#       Pokemon  HP  Ataque
# 0   bulbasaur  45      49
# 1     ivysaur  60      62
# 2    venusaur  80      82
# 3  charmander  39      52
# 4  charmeleon  58      64

# %%
#Extraindo o stats(2) e mesclando na dataframe base
df_defesa=df_stats[2].apply(pd.Series)
df_defesa=df_defesa[['base_stat']]
df_defesa = df_defesa.rename(columns={'base_stat': 'Defesa'})

pokedex_temp3 = pd.merge(pokedex_temp2, df_defesa, left_index=True, right_index=True)
pokedex_temp3.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa
# 0  bulbasaur  45      49      49
# 1    ivysaur  60      62      63
# 2   venusaur  80      82      83

# %%
#Extraindo o stats(3) e mesclando na dataframe base
df_ataque_especial=df_stats[3].apply(pd.Series)
df_ataque_especial=df_ataque_especial[['base_stat']]
df_ataque_especial = df_ataque_especial.rename(columns={'base_stat': 'Ataque Especial'})

pokedex_temp4 = pd.merge(pokedex_temp3, df_ataque_especial, left_index=True, right_index=True)
pokedex_temp4.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial
# 0  bulbasaur  45      49      49               65
# 1    ivysaur  60      62      63               80
# 2   venusaur  80      82      83              100

# %%
#Extraindo o stats(4) e mesclando na dataframe base
df_defesa_especial=df_stats[4].apply(pd.Series)
df_defesa_especial=df_defesa_especial[['base_stat']]
df_defesa_especial = df_defesa_especial.rename(columns={'base_stat': 'Defesa Especial'})

pokedex_temp5 = pd.merge(pokedex_temp4, df_defesa_especial, left_index=True, right_index=True)
pokedex_temp5.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100

# %%
#Extraindo o stats(5) e mesclando na dataframe base

df_velocidade=df_stats[5].apply(pd.Series)
df_velocidade=df_velocidade[['base_stat']]
df_velocidade = df_velocidade.rename(columns={'base_stat': 'Velocidade'})

pokedex_temp6 = pd.merge(pokedex_temp5, df_velocidade, left_index=True, right_index=True)
pokedex_temp6.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  Velocidade
# 0  bulbasaur  45      49      49               65               65          45
# 1    ivysaur  60      62      63               80               80          60
# 2   venusaur  80      82      83              100              100          80

# %%
#Extraindo a altura e mesclando na dataframe base

df_altura = df[['height']]
df_altura = df_altura['height'].apply(pd.Series)
df_altura = df_altura.rename(columns={0: 'Altura'})


pokedex_temp7 = pd.merge(pokedex_temp6, df_altura, left_index=True, right_index=True)
pokedex_temp7.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura
# 0          45       7
# 1          60      10
# 2          80      20

# %%
#Extraindo o peso e mesclando na dataframe base

df_peso = df[['weight']]
df_peso = df_peso['weight'].apply(pd.Series)
df_peso = df_peso.rename(columns={0: 'Peso'})

pokedex_temp8 = pd.merge(pokedex_temp7, df_peso, left_index=True, right_index=True)
pokedex_temp8.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso
# 0          45       7    69
# 1          60      10   130
# 2          80      20  1000

# %%
##Localização dos Pokemons

# %%
#Na requisição original temos um campo com urls de requisiçao de detalhes de "área de localização"
#As urls vão ser armazenadas no dataframe df_local
#É preciso criar um loop para interar entre linhas do dataframe df_local e coletar detalhes da localização
#Requisições serão armazenadas na lista req_local


df_local=df[['location_area_encounters']]

req_local = []
for i in df_local['location_area_encounters']:
  x = get_informacoes(i).json()
  req_local.append(x)

#OBS: somente os Pokemons originais tem localização, as evoluções não tem

# %%
#Informações de localização coletadas na requisição ficam armazanadas no dataframe df_localizacao
df_localizacao = pd.DataFrame(req_local)

# %%
#Extraindo a localização 1 e mesclando na dataframe base
temp_local1=df_localizacao[0].apply(pd.Series)

df_localizacao_1=temp_local1['location_area'].apply(pd.Series)
df_localizacao_1=df_localizacao_1[['name']]
df_localizacao_1 = df_localizacao_1.rename(columns={'name': 'Local 1'})

pokedex_temp9 = pd.merge(pokedex_temp8, df_localizacao_1, left_index=True, right_index=True)
pokedex_temp9.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1
# 0          45       7    69  cerulean-city-area
# 1          60      10   130                 NaN
# 2          80      20  1000                 NaN

# %%
#Extraindo a localização 1 e mesclando na dataframe base
temp_local2=df_localizacao[1].apply(pd.Series)

df_localizacao_2=temp_local2['location_area'].apply(pd.Series)
df_localizacao_2=df_localizacao_2[['name']]
df_localizacao_2 = df_localizacao_2.rename(columns={'name': 'Local 2'})

pokedex_temp10 = pd.merge(pokedex_temp9, df_localizacao_2, left_index=True, right_index=True)
pokedex_temp10.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2
# 0          45       7    69  cerulean-city-area  pallet-town-area
# 1          60      10   130                 NaN               NaN
# 2          80      20  1000                 NaN               NaN

# %%
##Habilidades dos Pokemons

# %%
#Criando dataframe  df_habilidades para armazenar dados semi-tratados req_informacoes

df_habilidades = pd.DataFrame(req_informacoes)
df_habilidades = df_habilidades[['abilities']]
df_habilidades = df_habilidades['abilities'].apply(pd.Series)

df_habilidades.head(3)
# Out:
#                                                    0  \
# 0  {'ability': {'name': 'overgrow', 'url': 'https...
# 1  {'ability': {'name': 'overgrow', 'url': 'https...
# 2  {'ability': {'name': 'overgrow', 'url': 'https...
#
#                                                    1    2
# 0  {'ability': {'name': 'chlorophyll', 'url': 'ht...  NaN
# 1  {'ability': {'name': 'chlorophyll', 'url': 'ht...  NaN
# 2  {'ability': {'name': 'chlorophyll', 'url': 'ht...  NaN

# %%
#Extraindo a habilidade 1 e mesclando na dataframe base

df_hab1=df_habilidades[0].apply(pd.Series)
df_hab1=df_hab1['ability'].apply(pd.Series)
df_hab1=df_hab1[['name']]
df_hab1 = df_hab1.rename(columns={'name': 'Habilidade 1'})

pokedex_temp11 = pd.merge(pokedex_temp10, df_hab1, left_index=True, right_index=True)
pokedex_temp11.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2 Habilidade 1
# 0          45       7    69  cerulean-city-area  pallet-town-area     overgrow
# 1          60      10   130                 NaN               NaN     overgrow
# 2          80      20  1000                 NaN               NaN     overgrow

# %%
#Extraindo a habilidade 1 e mesclando na dataframe base

df_hab2=df_habilidades[1].apply(pd.Series)
df_hab2=df_hab2['ability'].apply(pd.Series)
df_hab2=df_hab2[['name']]
df_hab2 = df_hab2.rename(columns={'name': 'Habilidade 2'})

pokedex_temp12 = pd.merge(pokedex_temp11, df_hab2, left_index=True, right_index=True)
pokedex_temp12.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2  \
# 0          45       7    69  cerulean-city-area  pallet-town-area
# 1          60      10   130                 NaN               NaN
# 2          80      20  1000                 NaN               NaN
#
#   Habilidade 1 Habilidade 2
# 0     overgrow  chlorophyll
# 1     overgrow  chlorophyll
# 2     overgrow  chlorophyll

# %%
##Movimentos dos Pokemons

# %%
#Cada pokemon tem vários movimentos possíveis, vamos extrair os 6 primeiros para montar a pokedex
#Informações de moves coletadas ficam armazanadas no dataframe df_moves

df_moves = df['moves'].apply(pd.Series)
df_moves.head()
# Out:
#                                                  0    \
# 0  {'move': {'name': 'razor-wind', 'url': 'https:...
# 1  {'move': {'name': 'swords-dance', 'url': 'http...
# 2  {'move': {'name': 'swords-dance', 'url': 'http...
# 3  {'move': {'name': 'mega-punch', 'url': 'https:...
# 4  {'move': {'name': 'mega-punch', 'url': 'https:...
#
#                                                  1    \
# 0  {'move': {'name': 'swords-dance', 'url': 'http...
# 1  {'move': {'name': 'cut', 'url': 'https://pokea...
# 2  {'move': {'name': 'cut', 'url': 'https://pokea...
# 3  {'move': {'name': 'fire-punch', 'url': 'https:...
# 4  {'move': {'name': 'fire-punch', 'url': 'https:...
#
#                                                  2    \
# 0  {'move': {'name': 'cut', 'url': 'https://pokea...
# 1  {'move': {'name': 'bind', 'url': 'https://poke...
# 2  {'move': {'name': 'bind', 'url': 'https://poke...
# 3  {'move': {'name': 'thunder-punch', 'url': 'htt...
# 4  {'move': {'name': 'thunder-punch', 'url': 'htt...
#
#                                                  3    \
# 0  {'move': {'name': 'bind', 'url': 'https://poke...
# 1  {'move': {'name': 'vine-whip', 'url': 'https:/...
# 2  {'move': {'name': 'vine-whip', 'url': 'https:/...
# 3  {'move': {'name': 'scratch', 'url': 'https://p...
# 4  {'move': {'name': 'scratch', 'url': 'https://p...
#
#                                                  4    \
# 0  {'move': {'name': 'vine-whip', 'url': 'https:/...
# 1  {'move': {'name': 'headbutt', 'url': 'https://...
# 2  {'move': {'name': 'headbutt', 'url': 'https://...
# 3  {'move': {'name': 'swords-dance', 'url': 'http...
# 4  {'move': {'name': 'swords-dance', 'url': 'http...
#
#                                                  5    \
# 0  {'move': {'name': 'headbutt', 'url': 'https://...
# 1  {'move': {'name': 'tackle', 'url': 'https://po...
# 2  {'move': {'name': 'tackle', 'url': 'https://po...
# 3  {'move': {'name': 'cut', 'url': 'https://pokea...
# 4  {'move': {'name': 'cut', 'url': 'https://pokea...
#
#                                                  6    \
# 0  {'move': {'name': 'tackle', 'url': 'https://po...
# 1  {'move': {'name': 'body-slam', 'url': 'https:/...
# 2  {'move': {'name': 'body-slam', 'url': 'https:/...
# 3  {'move': {'name': 'wing-attack', 'url': 'https...
# 4  {'move': {'name': 'mega-kick', 'url': 'https:/...
#
#                                                  7    \
# 0  {'move': {'name': 'body-slam', 'url': 'https:/...
# 1  {'move': {'name': 'take-down', 'url': 'https:/...
# 2  {'move': {'name': 'take-down', 'url': 'https:/...
# 3  {'move': {'name': 'mega-kick', 'url': 'https:/...
# 4  {'move': {'name': 'headbutt', 'url': 'https://...
#
#                                                  8    \
# 0  {'move': {'name': 'take-down', 'url': 'https:/...
# 1  {'move': {'name': 'double-edge', 'url': 'https...
# 2  {'move': {'name': 'double-edge', 'url': 'https...
# 3  {'move': {'name': 'headbutt', 'url': 'https://...
# 4  {'move': {'name': 'body-slam', 'url': 'https:/...
#
#                                                  9    ...  332  333  334  335  \
# 0  {'move': {'name': 'double-edge', 'url': 'https...  ...  NaN  NaN  NaN  NaN
# 1  {'move': {'name': 'growl', 'url': 'https://pok...  ...  NaN  NaN  NaN  NaN
# 2  {'move': {'name': 'growl', 'url': 'https://pok...  ...  NaN  NaN  NaN  NaN
# 3  {'move': {'name': 'body-slam', 'url': 'https:/...  ...  NaN  NaN  NaN  NaN
# 4  {'move': {'name': 'take-down', 'url': 'https:/...  ...  NaN  NaN  NaN  NaN
#
#    336  337  338  339  340  341
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 342 columns]

# %%
#Extraindo o movimento 1 e mesclando na dataframe base

df_move1=df_moves[0].apply(pd.Series)
df_move1=df_move1['move'].apply(pd.Series)
df_move1=df_move1[['name']]
df_move1 = df_move1.rename(columns={'name': 'Movimento 1'})

pokedex_temp13 = pd.merge(pokedex_temp12, df_move1, left_index=True, right_index=True)
pokedex_temp13.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2  \
# 0          45       7    69  cerulean-city-area  pallet-town-area
# 1          60      10   130                 NaN               NaN
# 2          80      20  1000                 NaN               NaN
#
#   Habilidade 1 Habilidade 2   Movimento 1
# 0     overgrow  chlorophyll    razor-wind
# 1     overgrow  chlorophyll  swords-dance
# 2     overgrow  chlorophyll  swords-dance

# %%
#Extraindo o movimento 2 e mesclando na dataframe base

df_move2=df_moves[1].apply(pd.Series)
df_move2=df_move2['move'].apply(pd.Series)
df_move2=df_move2[['name']]
df_move2 = df_move2.rename(columns={'name': 'Movimento 2'})

pokedex_temp14 = pd.merge(pokedex_temp13, df_move2, left_index=True, right_index=True)
pokedex_temp14.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2  \
# 0          45       7    69  cerulean-city-area  pallet-town-area
# 1          60      10   130                 NaN               NaN
# 2          80      20  1000                 NaN               NaN
#
#   Habilidade 1 Habilidade 2   Movimento 1   Movimento 2
# 0     overgrow  chlorophyll    razor-wind  swords-dance
# 1     overgrow  chlorophyll  swords-dance           cut
# 2     overgrow  chlorophyll  swords-dance           cut

# %%
#Extraindo o movimento 3 e mesclando na dataframe base

df_move3=df_moves[2].apply(pd.Series)
df_move3=df_move3['move'].apply(pd.Series)
df_move3=df_move3[['name']]
df_move3 = df_move3.rename(columns={'name': 'Movimento 3'})

pokedex_temp15 = pd.merge(pokedex_temp14, df_move3, left_index=True, right_index=True)
pokedex_temp15.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2  \
# 0          45       7    69  cerulean-city-area  pallet-town-area
# 1          60      10   130                 NaN               NaN
# 2          80      20  1000                 NaN               NaN
#
#   Habilidade 1 Habilidade 2   Movimento 1   Movimento 2 Movimento 3
# 0     overgrow  chlorophyll    razor-wind  swords-dance         cut
# 1     overgrow  chlorophyll  swords-dance           cut        bind
# 2     overgrow  chlorophyll  swords-dance           cut        bind

# %%
#Extraindo o movimento 4 e mesclando na dataframe base

df_move4=df_moves[3].apply(pd.Series)
df_move4=df_move4['move'].apply(pd.Series)
df_move4=df_move4[['name']]
df_move4 = df_move4.rename(columns={'name': 'Movimento 4'})

pokedex_temp16 = pd.merge(pokedex_temp15, df_move4, left_index=True, right_index=True)
pokedex_temp16.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2  \
# 0          45       7    69  cerulean-city-area  pallet-town-area
# 1          60      10   130                 NaN               NaN
# 2          80      20  1000                 NaN               NaN
#
#   Habilidade 1 Habilidade 2   Movimento 1   Movimento 2 Movimento 3  \
# 0     overgrow  chlorophyll    razor-wind  swords-dance         cut
# 1     overgrow  chlorophyll  swords-dance           cut        bind
# 2     overgrow  chlorophyll  swords-dance           cut        bind
#
#   Movimento 4
# 0        bind
# 1   vine-whip
# 2   vine-whip

# %%
#Extraindo o movimento 5 e mesclando na dataframe base

df_move5=df_moves[4].apply(pd.Series)
df_move5=df_move5['move'].apply(pd.Series)
df_move5=df_move5[['name']]
df_move5 = df_move5.rename(columns={'name': 'Movimento 5'})

pokedex_temp17 = pd.merge(pokedex_temp16, df_move5, left_index=True, right_index=True)
pokedex_temp17.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2  \
# 0          45       7    69  cerulean-city-area  pallet-town-area
# 1          60      10   130                 NaN               NaN
# 2          80      20  1000                 NaN               NaN
#
#   Habilidade 1 Habilidade 2   Movimento 1   Movimento 2 Movimento 3  \
# 0     overgrow  chlorophyll    razor-wind  swords-dance         cut
# 1     overgrow  chlorophyll  swords-dance           cut        bind
# 2     overgrow  chlorophyll  swords-dance           cut        bind
#
#   Movimento 4 Movimento 5
# 0        bind   vine-whip
# 1   vine-whip    headbutt
# 2   vine-whip    headbutt

# %%
#Extraindo o movimento 6 e mesclando na dataframe base

df_move6=df_moves[5].apply(pd.Series)
df_move6=df_move6['move'].apply(pd.Series)
df_move6=df_move6[['name']]
df_move6 = df_move6.rename(columns={'name': 'Movimento 6'})

pokedex_temp18 = pd.merge(pokedex_temp17, df_move6, left_index=True, right_index=True)
pokedex_temp18.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2  \
# 0          45       7    69  cerulean-city-area  pallet-town-area
# 1          60      10   130                 NaN               NaN
# 2          80      20  1000                 NaN               NaN
#
#   Habilidade 1 Habilidade 2   Movimento 1   Movimento 2 Movimento 3  \
# 0     overgrow  chlorophyll    razor-wind  swords-dance         cut
# 1     overgrow  chlorophyll  swords-dance           cut        bind
# 2     overgrow  chlorophyll  swords-dance           cut        bind
#
#   Movimento 4 Movimento 5 Movimento 6
# 0        bind   vine-whip    headbutt
# 1   vine-whip    headbutt      tackle
# 2   vine-whip    headbutt      tackle

# %%
##Imagens dos Pokemons

# %%
#Estudando a API, sei que em 'sprites' > 'front_shiny' armazena o link para a imagem png de cada pokemon
#Extraindo o link da image e mesclando na dataframe base para criar o arquivo final

df_imagem = df['sprites'].apply(pd.Series)
df_imagem=df_imagem[['front_shiny']]
df_imagem = df_imagem.rename(columns={'front_shiny': 'Imagem'})

pokedex_temp19 = pd.merge(pokedex_temp18, df_imagem, left_index=True, right_index=True)
pokedex_temp19.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1           Local 2  \
# 0          45       7    69  cerulean-city-area  pallet-town-area
# 1          60      10   130                 NaN               NaN
# 2          80      20  1000                 NaN               NaN
#
#   Habilidade 1 Habilidade 2   Movimento 1   Movimento 2 Movimento 3  \
# 0     overgrow  chlorophyll    razor-wind  swords-dance         cut
# 1     overgrow  chlorophyll  swords-dance           cut        bind
# 2     overgrow  chlorophyll  swords-dance           cut        bind
#
#   Movimento 4 Movimento 5 Movimento 6  \
# 0        bind   vine-whip    headbutt
# 1   vine-whip    headbutt      tackle
# 2   vine-whip    headbutt      tackle
#
#                                               Imagem
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
# 1  https://raw.githubusercontent.com/PokeAPI/spri...
# 2  https://raw.githubusercontent.com/PokeAPI/spri...

# %%
df.head()
# Out:
#                                            abilities  base_experience  \
# 0  [{'ability': {'name': 'overgrow', 'url': 'http...               64
# 1  [{'ability': {'name': 'overgrow', 'url': 'http...              142
# 2  [{'ability': {'name': 'overgrow', 'url': 'http...              263
# 3  [{'ability': {'name': 'blaze', 'url': 'https:/...               62
# 4  [{'ability': {'name': 'blaze', 'url': 'https:/...              142
#
#                                                forms  \
# 0  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1  [{'name': 'ivysaur', 'url': 'https://pokeapi.c...
# 2  [{'name': 'venusaur', 'url': 'https://pokeapi....
# 3  [{'name': 'charmander', 'url': 'https://pokeap...
# 4  [{'name': 'charmeleon', 'url': 'https://pokeap...
#
#                                         game_indices  height held_items  id  \
# 0  [{'game_index': 153, 'version': {'name': 'red'...       7         []   1
# 1  [{'game_index': 9, 'version': {'name': 'red', ...      10         []   2
# 2  [{'game_index': 154, 'version': {'name': 'red'...      20         []   3
# 3  [{'game_index': 176, 'version': {'name': 'red'...       6         []   4
# 4  [{'game_index': 178, 'version': {'name': 'red'...      11         []   5
#
#    is_default                        location_area_encounters  \
# 0        True  https://pokeapi.co/api/v2/pokemon/1/encounters
# 1        True  https://pokeapi.co/api/v2/pokemon/2/encounters
# 2        True  https://pokeapi.co/api/v2/pokemon/3/encounters
# 3        True  https://pokeapi.co/api/v2/pokemon/4/encounters
# 4        True  https://pokeapi.co/api/v2/pokemon/5/encounters
#
#                                                moves        name  order  \
# 0  [{'move': {'name': 'razor-wind', 'url': 'https...   bulbasaur      1
# 1  [{'move': {'name': 'swords-dance', 'url': 'htt...     ivysaur      2
# 2  [{'move': {'name': 'swords-dance', 'url': 'htt...    venusaur      3
# 3  [{'move': {'name': 'mega-punch', 'url': 'https...  charmander      5
# 4  [{'move': {'name': 'mega-punch', 'url': 'https...  charmeleon      6
#
#   past_types                                            species  \
# 0         []  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 1         []  {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 2         []  {'name': 'venusaur', 'url': 'https://pokeapi.c...
# 3         []  {'name': 'charmander', 'url': 'https://pokeapi...
# 4         []  {'name': 'charmeleon', 'url': 'https://pokeapi...
#
#                                              sprites  \
# 0  {'back_default': 'https://raw.githubuserconten...
# 1  {'back_default': 'https://raw.githubuserconten...
# 2  {'back_default': 'https://raw.githubuserconten...
# 3  {'back_default': 'https://raw.githubuserconten...
# 4  {'back_default': 'https://raw.githubuserconten...
#
#                                                stats  \
# 0  [{'base_stat': 45, 'effort': 0, 'stat': {'name...
# 1  [{'base_stat': 60, 'effort': 0, 'stat': {'name...
# 2  [{'base_stat': 80, 'effort': 0, 'stat': {'name...
# 3  [{'base_stat': 39, 'effort': 0, 'stat': {'name...
# 4  [{'base_stat': 58, 'effort': 0, 'stat': {'name...
#
#                                                types  weight
# 0  [{'slot': 1, 'type': {'name': 'grass', 'url': ...      69
# 1  [{'slot': 1, 'type': {'name': 'grass', 'url': ...     130
# 2  [{'slot': 1, 'type': {'name': 'grass', 'url': ...    1000
# 3  [{'slot': 1, 'type': {'name': 'fire', 'url': '...      85
# 4  [{'slot': 1, 'type': {'name': 'fire', 'url': '...     190

# %%
##Corrente Evolutiva dos Pokemons

# %%
#Criando loop para interar entre linhas do dataframe base df_especies
#Requisições serão armazenadas na lista req_informacoes

req_evolucao = []
for i in df['id']:
  link= "https://pokeapi.co/api/v2/pokemon-species/"+str(i)+"/"
  x = get_informacoes(link).json()
  req_evolucao.append(x)

# %%
#Criando o dataframe df_detalhes que armazena outras características de cada espécie
df_detalhes = pd.DataFrame(req_evolucao)
df_detalhes.head()
# Out:
#    base_happiness  capture_rate  \
# 0              50            45
# 1              50            45
# 2              50            45
# 3              50            45
# 4              50            45
#
#                                                color  \
# 0  {'name': 'green', 'url': 'https://pokeapi.co/a...
# 1  {'name': 'green', 'url': 'https://pokeapi.co/a...
# 2  {'name': 'green', 'url': 'https://pokeapi.co/a...
# 3  {'name': 'red', 'url': 'https://pokeapi.co/api...
# 4  {'name': 'red', 'url': 'https://pokeapi.co/api...
#
#                                           egg_groups  \
# 0  [{'name': 'monster', 'url': 'https://pokeapi.c...
# 1  [{'name': 'monster', 'url': 'https://pokeapi.c...
# 2  [{'name': 'monster', 'url': 'https://pokeapi.c...
# 3  [{'name': 'monster', 'url': 'https://pokeapi.c...
# 4  [{'name': 'monster', 'url': 'https://pokeapi.c...
#
#                                      evolution_chain  \
# 0  {'url': 'https://pokeapi.co/api/v2/evolution-c...
# 1  {'url': 'https://pokeapi.co/api/v2/evolution-c...
# 2  {'url': 'https://pokeapi.co/api/v2/evolution-c...
# 3  {'url': 'https://pokeapi.co/api/v2/evolution-c...
# 4  {'url': 'https://pokeapi.co/api/v2/evolution-c...
#
#                                 evolves_from_species  \
# 0                                               None
# 1  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 2  {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 3                                               None
# 4  {'name': 'charmander', 'url': 'https://pokeapi...
#
#                                  flavor_text_entries form_descriptions  \
# 0  [{'flavor_text': 'A strange seed was
# planted o...                []
# 1  [{'flavor_text': 'When the bulb on
# its back gr...                []
# 2  [{'flavor_text': 'The plant blooms
# when it is
# ...                []
# 3  [{'flavor_text': 'Obviously prefers
# hot places...                []
# 4  [{'flavor_text': 'When it swings
# its burning t...                []
#
#    forms_switchable  gender_rate  ... is_baby is_legendary is_mythical  \
# 0             False            1  ...   False        False       False
# 1             False            1  ...   False        False       False
# 2              True            1  ...   False        False       False
# 3             False            1  ...   False        False       False
# 4             False            1  ...   False        False       False
#
#          name                                              names  order  \
# 0   bulbasaur  [{'language': {'name': 'ja-Hrkt', 'url': 'http...      1
# 1     ivysaur  [{'language': {'name': 'ja-Hrkt', 'url': 'http...      2
# 2    venusaur  [{'language': {'name': 'ja-Hrkt', 'url': 'http...      3
# 3  charmander  [{'language': {'name': 'ja-Hrkt', 'url': 'http...      4
# 4  charmeleon  [{'language': {'name': 'ja-Hrkt', 'url': 'http...      5
#
#                                  pal_park_encounters  \
# 0  [{'area': {'name': 'field', 'url': 'https://po...
# 1  [{'area': {'name': 'field', 'url': 'https://po...
# 2  [{'area': {'name': 'field', 'url': 'https://po...
# 3  [{'area': {'name': 'field', 'url': 'https://po...
# 4  [{'area': {'name': 'field', 'url': 'https://po...
#
#                                      pokedex_numbers  \
# 0  [{'entry_number': 1, 'pokedex': {'name': 'nati...
# 1  [{'entry_number': 2, 'pokedex': {'name': 'nati...
# 2  [{'entry_number': 3, 'pokedex': {'name': 'nati...
# 3  [{'entry_number': 4, 'pokedex': {'name': 'nati...
# 4  [{'entry_number': 5, 'pokedex': {'name': 'nati...
#
#                                                shape  \
# 0  {'name': 'quadruped', 'url': 'https://pokeapi....
# 1  {'name': 'quadruped', 'url': 'https://pokeapi....
# 2  {'name': 'quadruped', 'url': 'https://pokeapi....
# 3  {'name': 'upright', 'url': 'https://pokeapi.co...
# 4  {'name': 'upright', 'url': 'https://pokeapi.co...
#
#                                            varieties
# 0  [{'is_default': True, 'pokemon': {'name': 'bul...
# 1  [{'is_default': True, 'pokemon': {'name': 'ivy...
# 2  [{'is_default': True, 'pokemon': {'name': 'ven...
# 3  [{'is_default': True, 'pokemon': {'name': 'cha...
# 4  [{'is_default': True, 'pokemon': {'name': 'cha...
#
# [5 rows x 27 columns]

# %%
#Extraindo o pokemon origem e mesclando na dataframe base
df_evolucao=df_detalhes['evolves_from_species'].apply(pd.Series)
df_evolucao = df_evolucao[['name']]
df_evolucao = df_evolucao.rename(columns={'name': 'Pokemon Origem'})

pokedex_temp20 = pd.merge(pokedex_temp19, df_evolucao, left_index=True, right_index=True)
pokedex_temp20.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1  ... Habilidade 1  \
# 0          45       7    69  cerulean-city-area  ...     overgrow
# 1          60      10   130                 NaN  ...     overgrow
# 2          80      20  1000                 NaN  ...     overgrow
#
#   Habilidade 2   Movimento 1   Movimento 2 Movimento 3 Movimento 4  \
# 0  chlorophyll    razor-wind  swords-dance         cut        bind
# 1  chlorophyll  swords-dance           cut        bind   vine-whip
# 2  chlorophyll  swords-dance           cut        bind   vine-whip
#
#   Movimento 5 Movimento 6                                             Imagem  \
# 0   vine-whip    headbutt  https://raw.githubusercontent.com/PokeAPI/spri...
# 1    headbutt      tackle  https://raw.githubusercontent.com/PokeAPI/spri...
# 2    headbutt      tackle  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   Pokemon Origem
# 0            NaN
# 1      bulbasaur
# 2        ivysaur
#
# [3 rows x 21 columns]

# %%
#Extraindo a cor do pokemon e mesclando na dataframe base
df_cor =df_detalhes['color'].apply(pd.Series)
df_cor = df_cor[['name']]
df_cor = df_cor.rename(columns={'name': 'Cor'})

#Dataframe final
pokedex = pd.merge(pokedex_temp20, df_cor, left_index=True, right_index=True)
pokedex.head(3)
# Out:
#      Pokemon  HP  Ataque  Defesa  Ataque Especial  Defesa Especial  \
# 0  bulbasaur  45      49      49               65               65
# 1    ivysaur  60      62      63               80               80
# 2   venusaur  80      82      83              100              100
#
#    Velocidade  Altura  Peso             Local 1  ... Habilidade 2  \
# 0          45       7    69  cerulean-city-area  ...  chlorophyll
# 1          60      10   130                 NaN  ...  chlorophyll
# 2          80      20  1000                 NaN  ...  chlorophyll
#
#     Movimento 1   Movimento 2 Movimento 3 Movimento 4 Movimento 5 Movimento 6  \
# 0    razor-wind  swords-dance         cut        bind   vine-whip    headbutt
# 1  swords-dance           cut        bind   vine-whip    headbutt      tackle
# 2  swords-dance           cut        bind   vine-whip    headbutt      tackle
#
#                                               Imagem Pokemon Origem    Cor
# 0  https://raw.githubusercontent.com/PokeAPI/spri...            NaN  green
# 1  https://raw.githubusercontent.com/PokeAPI/spri...      bulbasaur  green
# 2  https://raw.githubusercontent.com/PokeAPI/spri...        ivysaur  green
#
# [3 rows x 22 columns]

# %%
#Salvando o dataframe final para formato CSV
pokedex.to_csv('pokedex.csv')
